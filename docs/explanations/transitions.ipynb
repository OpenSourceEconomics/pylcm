# %% [markdown]
# # The Transition System
#
# pylcm models involve two independent layers of transitions that compose during
# backward induction:
#
# 1. **State transitions** — how a state variable evolves over time
#    (attached to grids)
# 2. **Regime transitions** — which regime the agent enters next period (attached to
#    the regime itself)
#
# The two layers have opposite orientations:
#
# - **Regime transitions are forward-looking.** The `transition` field on a `Regime`
#   answers "where does the agent go next?" It lives on the *source* regime and
#   points toward the future.
# - **State transitions are backward-looking.** The `transition` parameter on a grid
#   answers "how did this state variable reach its current value?" It lives on the
#   grid that *receives* the value. In multi-regime models, per-boundary mappings
#   are placed on the *target* regime's grid.
#
# This notebook explains how each layer works, how per-boundary transitions handle
# cross-regime state differences, how transition parameters flow through the system,
# and how everything composes in the Bellman equation.

# %%
from pprint import pprint

import jax
import jax.numpy as jnp

from lcm import (
    DiscreteGrid,
    DiscreteMarkovGrid,
    LinSpacedGrid,
    Model,
    Regime,
    RegimeTransition,
    categorical,
)
from lcm.ages import AgeGrid
from lcm.typing import (
    ContinuousState,
    DiscreteState,
    FloatND,
    ScalarInt,
)

# %% [markdown]
# ## State Transition Mechanics
#
# State transitions are attached directly to grid objects via the `transition`
# parameter. There are four cases:
#
# | Grid configuration | Behavior |
# |---|---|
# | `transition=some_func` | Deterministic: $s' = f(s, a, \ldots)$ |
# | `transition=None` | Fixed: $s' = s$ (identity auto-generated) |
# | `DiscreteMarkovGrid(transition=func)` | Stochastic: probability-weighted expectation |
# | Shock grids (`lcm.shocks.*`) | Intrinsic transitions with interpolated weights |

# %% [markdown]
# ### Deterministic state transitions
#
# A state transition function defines how the next-period state value is determined
# from the current period's states, actions, and parameters. The function's argument
# names are resolved from the regime's namespace.

# %%
def next_wealth(
    wealth: ContinuousState,
    consumption: ContinuousState,
    interest_rate: float,
) -> ContinuousState:
    return (1 + interest_rate) * (wealth - consumption)


# Attached to the grid:
wealth_grid = LinSpacedGrid(start=0, stop=100, n_points=50, transition=next_wealth)

# %% [markdown]
# ### Fixed states and identity transitions
#
# When `transition=None`, pylcm auto-generates an identity transition internally.
# This shows up in `model.get_all_functions("regime_name")` under a boundary-encoded
# key like `"target__next_<state_name>"`.

# %%
@categorical
class EducationLevel:
    low: int
    high: int


@categorical
class RegimeId:
    working: int
    retired: int


def utility_simple(wealth: ContinuousState, education: DiscreteState) -> FloatND:
    return jnp.log(wealth + 1.0) + 0.5 * education


def next_regime_to_retired() -> ScalarInt:
    return RegimeId.retired


identity_model = Model(
    regimes={
        "working": Regime(
            transition=RegimeTransition(next_regime_to_retired),
            states={
                "education": DiscreteGrid(EducationLevel, transition=None),
                "wealth": LinSpacedGrid(start=0, stop=50, n_points=10, transition=None),
            },
            functions={"utility": utility_simple},
        ),
        "retired": Regime(
            transition=None,
            states={
                "education": DiscreteGrid(EducationLevel, transition=None),
                "wealth": LinSpacedGrid(start=0, stop=50, n_points=10, transition=None),
            },
            functions={"utility": utility_simple},
        ),
    },
    ages=AgeGrid(start=0, stop=2, step="Y"),
    regime_id_class=RegimeId,
)

all_funcs = identity_model.get_all_functions("working")
print("Function keys:", sorted(all_funcs.keys()))

identity_keys = sorted(k for k in all_funcs if "next_education" in k)
print("\nnext_education keys:", identity_keys)
print("Type:", type(all_funcs[identity_keys[0]]).__name__)

# %% [markdown]
# Both fixed states produce `_IdentityTransition` objects — one per regime boundary.
# These are marked with `_is_auto_identity = True` so that validation can
# distinguish them from user-provided transitions.

# %% [markdown]
# ### Stochastic state transitions (DiscreteMarkovGrid)
#
# For `DiscreteMarkovGrid`, the transition function returns a probability array over
# the categories. During the solve step, pylcm computes a probability-weighted
# expectation over next-period states:
#
# $$
# \mathbb{E}[V(s')] = \sum_{s'} P(s' \mid s) \, V(s')
# $$

# %%
@categorical
class Health:
    bad: int
    good: int


def health_transition(health: DiscreteState) -> FloatND:
    return jnp.where(
        health == Health.good,
        jnp.array([0.1, 0.9]),  # good -> 90% stay good
        jnp.array([0.6, 0.4]),  # bad  -> 40% recover
    )


health_grid = DiscreteMarkovGrid(Health, transition=health_transition)

# Inspect the transition probabilities
for state_name, state_code in [("bad", Health.bad), ("good", Health.good)]:
    probs = health_transition(jnp.array(state_code))
    print(f"P(next | {state_name}) = {probs}")

# %% [markdown]
# ### Shock grids
#
# Shock grids (from `lcm.shocks.iid` and `lcm.shocks.ar1`) have intrinsic
# transitions computed from the distribution. For IID shocks, the transition
# probabilities are the same regardless of the current value. For AR(1) shocks,
# probabilities depend on the current state.
#
# Shock grids do not accept a `transition` parameter — their transitions are
# built-in.

# %%
import lcm.shocks.iid

shock = lcm.shocks.iid.Normal(
    n_points=5, gauss_hermite=False, mu=0.0, sigma=1.0, n_std=2.5
)
print("Grid points:", shock.to_jax())

# %% [markdown]
# ## Per-Boundary State Transitions
#
# When a discrete state has different categories across regimes, a simple callable
# transition is not enough — you need to map from one category set to another at
# the regime boundary.
#
# The solution: a **mapping transition** keyed by `(source_regime, target_regime)`
# pairs, placed on the **target** regime's grid.

# %% [markdown]
# ### Example: different health categories
#
# Suppose working life has three health states (disabled, bad, good) but retirement
# only has two (bad, good). The transition from working to retired needs an explicit
# mapping.

# %%
@categorical
class HealthWorking:
    disabled: int
    bad: int
    good: int


@categorical
class HealthRetired:
    bad: int
    good: int


def map_working_to_retired(health: DiscreteState) -> DiscreteState:
    """Map 3-category working health to 2-category retired health."""
    return jnp.where(
        health == HealthWorking.good,
        HealthRetired.good,
        HealthRetired.bad,
    )


# Verify the mapping
for name, code in [("disabled", 0), ("bad", 1), ("good", 2)]:
    result = map_working_to_retired(jnp.array(code))
    print(f"working {name} ({code}) -> retired code {int(result)}")

# %% [markdown]
# The mapping is placed on the target regime's grid:

# %%
health_retired_grid = DiscreteGrid(
    HealthRetired,
    transition={
        ("working", "retired"): map_working_to_retired,
    },
)

# %% [markdown]
# ### Resolution priority
#
# When resolving which transition function to use at a regime boundary `(source,
# target)`, pylcm checks (in order):
#
# 1. Target grid mapping for `(source, target)`
# 2. Source grid mapping for `(source, target)`
# 3. Source grid's callable transition
# 4. Target grid's callable transition
# 5. Auto-generated identity (if categories match)
#
# If the categories differ across regimes and no explicit mapping is found,
# `ModelInitializationError` is raised.

# %% [markdown]
# ## How Transition Parameters Work
#
# State transition functions often take **parameters** beyond the state and action
# variables — interest rates, growth rates, tax rates. In a multi-regime model,
# each regime boundary is a separate scope for transition parameters.
#
# The params template uses **boundary-pair keys** with the `_to_` separator to
# distinguish between boundaries:
#
# ```
# regime_name           -> non-transition functions (utility, constraints, H)
# source_to_target      -> transition functions at that specific boundary
# ```
#
# This means the same transition function can receive different parameter values
# depending on which boundary it operates at.

# %% [markdown]
# ### Example: growth rate that varies by boundary
#
# Consider a model with two phases. In the growing phase, wealth evolves according
# to a `growth_rate` parameter. The question is: should the growth rate be the
# same when staying in the growing phase vs. when transitioning to the stable
# phase?
#
# With boundary-pair keys, each boundary gets its own parameter namespace, so you
# can set them independently — or use a single value for all boundaries.

# %%
@categorical
class PhaseId:
    growing: int
    stable: int


def utility_crra(wealth: ContinuousState, risk_aversion: float) -> FloatND:
    return wealth ** (1 - risk_aversion) / (1 - risk_aversion)


def next_wealth_growth(
    wealth: ContinuousState,
    growth_rate: float,
) -> ContinuousState:
    return (1 + growth_rate) * wealth


def next_regime_to_stable() -> ScalarInt:
    return PhaseId.stable


growing = Regime(
    transition=RegimeTransition(next_regime_to_stable),
    states={
        "wealth": LinSpacedGrid(
            start=1, stop=100, n_points=20, transition=next_wealth_growth
        ),
    },
    functions={"utility": utility_crra},
)

stable = Regime(
    transition=None,
    states={
        "wealth": LinSpacedGrid(start=1, stop=100, n_points=20, transition=None),
    },
    functions={"utility": utility_crra},
)

growth_model = Model(
    regimes={"growing": growing, "stable": stable},
    ages=AgeGrid(start=0, stop=2, step="Y"),
    regime_id_class=PhaseId,
)

# %%
pprint(dict(growth_model.params_template))

# %% [markdown]
# The template has four top-level keys:
#
# - `"growing"` — non-transition functions (`H`, `utility`, `next_regime`)
# - `"growing_to_growing"` — wealth transition when staying in the growing regime
# - `"growing_to_stable"` — wealth transition when moving to the stable regime
# - `"stable"` — the terminal regime's functions (`utility` only)
#
# `growth_rate` appears independently under both pair keys. Each boundary can have
# a different growth rate.

# %% [markdown]
# ### Five levels of parameter specification
#
# When you call `model.solve(params)`, pylcm resolves each required parameter by
# checking five levels, from most specific to least specific:
#
# | Level | Example | Scope |
# |---|---|---|
# | 1. Function | `{"growing_to_stable": {"next_wealth": {"growth_rate": 0.02}}}` | Exact match for one function at one boundary |
# | 2. Pair/regime | `{"growing_to_stable": {"growth_rate": 0.02}}` | All functions at one boundary |
# | 3. Source-function | `{"growing": {"next_wealth": {"growth_rate": 0.05}}}` | One function at all boundaries from growing |
# | 4. Source-regime | `{"growing": {"growth_rate": 0.05}}` | All boundaries from growing |
# | 5. Model | `{"growth_rate": 0.05}` | Everywhere |
#
# Levels 3 and 4 are a convenience for multi-regime models: setting a transition
# parameter under the source regime name propagates it to all boundaries
# originating from that regime.
#
# **Ambiguity rule:** The same parameter cannot be specified at multiple levels
# within the same resolution path. If `growth_rate` appears at both model level
# and pair level for the same boundary, `InvalidNameError` is raised.

# %% [markdown]
# ### Uniform growth rate (model level)
#
# When all boundaries share the same growth rate, specify it at the model level:

# %%
params_uniform = {
    "risk_aversion": 0.5,
    "discount_factor": 0.95,
    "growth_rate": 0.05,
}

V = growth_model.solve(params_uniform, debug_mode=False)
print("Solved with uniform growth_rate = 0.05 at all boundaries")

# %% [markdown]
# ### Different growth rates per boundary (pair level)
#
# To set different growth rates depending on which boundary the agent crosses,
# use pair keys:

# %%
params_per_boundary = {
    "risk_aversion": 0.5,
    "discount_factor": 0.95,
    "growing_to_growing": {"growth_rate": 0.05},
    "growing_to_stable": {"growth_rate": 0.00},
}

V = growth_model.solve(params_per_boundary, debug_mode=False)
print("Solved: growth_rate = 0.05 within growing, 0.00 at boundary to stable")

# %% [markdown]
# ### Source-regime shorthand
#
# When all boundaries from a source regime share the same parameter values,
# you can specify them under the source regime name. This is especially convenient
# when migrating from single-regime models or when per-boundary differentiation
# is not needed:

# %%
params_source = {
    "risk_aversion": 0.5,
    "discount_factor": 0.95,
    "growing": {"growth_rate": 0.05},
}

V = growth_model.solve(params_source, debug_mode=False)
print("Solved with growth_rate = 0.05 via source-regime shorthand")

# %% [markdown]
# ### Per-boundary mappings with different functions
#
# A more powerful pattern: the target grid provides a completely different
# transition function at a specific boundary. For example, wealth grows normally
# within the growing regime but faces a one-time tax when crossing to the stable
# regime:

# %%
def next_wealth_at_retirement(
    wealth: ContinuousState,
    tax_rate: float,
) -> ContinuousState:
    """Wealth transition at the growing -> stable boundary."""
    return wealth * (1 - tax_rate)


stable_with_tax = Regime(
    transition=None,
    states={
        "wealth": LinSpacedGrid(
            start=1,
            stop=100,
            n_points=20,
            transition={("growing", "stable"): next_wealth_at_retirement},
        ),
    },
    functions={"utility": utility_crra},
)

tax_model = Model(
    regimes={"growing": growing, "stable": stable_with_tax},
    ages=AgeGrid(start=0, stop=2, step="Y"),
    regime_id_class=PhaseId,
)

pprint(dict(tax_model.params_template))

# %% [markdown]
# Now the two pair keys have **different parameters**:
#
# - `"growing_to_growing"` has `growth_rate` (from the source grid's callable)
# - `"growing_to_stable"` has `tax_rate` (from the target grid's per-boundary mapping)
#
# Each boundary uses a different transition function with its own parameter set.
# Since there is no ambiguity, both can be specified at model level:

# %%
params_tax = {
    "risk_aversion": 0.5,
    "discount_factor": 0.95,
    "growth_rate": 0.05,
    "tax_rate": 0.20,
}

V = tax_model.solve(params_tax, debug_mode=False)
print("Solved: growth_rate = 0.05 (within), tax_rate = 0.20 (at boundary)")

# %% [markdown]
# ## Regime Transition Mechanics
#
# Regime transitions determine which regime the agent enters next period. Internally,
# both deterministic and stochastic transitions are converted to a uniform probability
# array format.

# %% [markdown]
# ### Deterministic transitions -> one-hot encoding
#
# A `RegimeTransition` wraps a function that returns an integer regime ID.
# Internally, pylcm converts this to a one-hot probability array using
# `jax.nn.one_hot`:

# %%
@categorical
class RegimeIdExample:
    working: int
    retired: int
    dead: int


def next_regime_det(age: float, retirement_age: float) -> ScalarInt:
    return jnp.where(
        age >= retirement_age, RegimeIdExample.retired, RegimeIdExample.working
    )


# What pylcm does internally:
regime_idx = next_regime_det(age=50.0, retirement_age=65.0)
one_hot = jax.nn.one_hot(regime_idx, num_classes=3)
print(f"Regime index: {int(regime_idx)}")
print(f"One-hot:      {one_hot}  (= [P(working), P(retired), P(dead)])")

# %% [markdown]
# ### Stochastic transitions -> probability array
#
# A `MarkovRegimeTransition` wraps a function that directly returns a probability
# array. No conversion is needed — the array is used as-is.

# %%
def next_regime_stoch(survival_prob: float) -> FloatND:
    """Alive -> [P(working), P(retired), P(dead)]."""
    return jnp.array([survival_prob, 0.0, 1 - survival_prob])


probs = next_regime_stoch(survival_prob=0.98)
print(f"Probabilities: {probs}  (= [P(working), P(retired), P(dead)])")

# %% [markdown]
# After wrapping, the probability array is converted to a dictionary keyed by
# regime name, giving a uniform internal representation regardless of whether the
# original transition was deterministic or stochastic.

# %% [markdown]
# ## How Transitions Compose in the Bellman Equation
#
# The value function computation depends on the regime type.

# %% [markdown]
# ### Terminal regimes
#
# No continuation value. The value function equals the utility directly:
#
# $$
# V_T(s) = U(s)
# $$

# %% [markdown]
# ### Non-terminal with deterministic regime transition
#
# The continuation value comes from a single next-period regime:
#
# $$
# V_t(s) = \max_a \left\{ U(s, a) + \beta \, V_{t+1}^{r'}(s') \right\}
# $$
#
# where $r'$ is the deterministically chosen next regime and $s' = g(s, a)$ is the
# next-period state.

# %% [markdown]
# ### Non-terminal with stochastic regime transition
#
# The continuation value is an expectation over possible next regimes:
#
# $$
# V_t(s) = \max_a \left\{ U(s, a) + \beta \sum_r p_r \, V_{t+1}^{r}(s') \right\}
# $$
#
# where $p_r$ is the probability of transitioning to regime $r$.

# %% [markdown]
# ### Adding stochastic state transitions
#
# When a state has a Markov transition (`DiscreteMarkovGrid`) or shock grid, an
# additional layer of expectation is added inside the max:
#
# $$
# V_t(s) = \max_a \left\{ U(s, a) + \beta \sum_r p_r
#     \sum_{s'} P(s' \mid s) \, V_{t+1}^{r}(s') \right\}
# $$
#
# The inner sum handles the stochastic state transition; the outer sum handles the
# stochastic regime transition. When either is deterministic, its corresponding sum
# collapses to a single term.

# %% [markdown]
# (transitions-summary)=
#
# ### Summary
#
# | Component | Deterministic | Stochastic |
# |---|---|---|
# | State transition | $s' = g(s, a)$ | $\sum_{s'} P(s' \mid s) \, V(s')$ |
# | Regime transition | One-hot $\rightarrow$ single $V^{r'}$ | $\sum_r p_r \, V^r$ |
# | Internal format | Both converted to probability arrays | — |
#
# The uniform probability format means the backward induction algorithm treats all
# transitions the same way — deterministic transitions are just the special case
# where one probability is 1 and the rest are 0.

# %% [markdown]
# ## Internals: How Transitions Are Processed
#
# ```{admonition} Developer documentation
# :class: important
#
# This section is for library developers working on the pylcm internals. Users can
# skip to the [summary table](#transitions-summary) above.
# ```

# %% [markdown]
# ### Boundary-encoded transition names
#
# Internally, `collect_all_regime_functions` (in `process_transitions.py`) resolves
# all transitions for every regime and returns two things per regime:
#
# - **`all_functions`** — a flat dict mapping function names to callables
# - **`transition_keys`** — a frozenset identifying which names are transitions
#
# Transition functions are stored with boundary-encoded names that embed the
# **target** regime using `QNAME_DELIMITER` (`__`):
#
# - `"retired__next_wealth"` — transition targeting the retired regime
# - `"working__next_wealth"` — transition targeting the working regime (self-loop)
#
# Non-transition functions (`utility`, `H`, constraints) keep their plain names.
# The regime transition function uses the plain name `"next_regime"`.

# %% [markdown]
# ### Params template construction
#
# The params template uses `REGIME_PAIR_SEPARATOR` (`_to_`) to convert internal
# boundary-encoded names into user-facing pair keys:
#
# - Internal key: `"stable__next_wealth"` (in the growing regime's functions)
# - Pair key: `"growing_to_stable"` (in the params template)
#
# The pair-key format keeps qualified names (qnames) at exactly 3 parts:
#
# ```
# growing_to_stable__next_wealth__growth_rate
# |--- pair key ---|  |- function -|  |- param -|
# ```
#
# This fits the existing parameter resolution logic: the first part is a regime
# name or pair key, the second is a function name, and the third is a parameter
# name.

# %% [markdown]
# ### Parameter renaming and compilation
#
# `_rename_params_to_qnames` maps simple parameter names in function signatures
# to their fully qualified forms:
#
# ```
# growth_rate  ->  growing_to_stable__next_wealth__growth_rate
# ```
#
# After renaming, `flat_param_names` is a frozenset of all flattened template keys.
# The compilation pipeline uses this set to exclude parameters from `vmap` —
# parameters are scalar values that must not be batched over states and actions.

# %% [markdown]
# ### Runtime parameter resolution
#
# At solve/simulate time, `process_params` flattens the user-provided params dict
# and matches each entry against the template using `_find_candidates`. For each
# template qname, five levels are checked:
#
# 1. **Exact:** `growing_to_stable__next_wealth__growth_rate`
# 2. **Pair level:** `growing_to_stable__growth_rate`
# 3. **Source-function:** `growing__next_wealth__growth_rate`
# 4. **Source-regime:** `growing__growth_rate`
# 5. **Model level:** `growth_rate`
#
# Levels 3 and 4 only apply to pair keys (those containing `_to_`). For plain
# regime keys like `"growing"`, only levels 1, 2, and 5 are checked — these are the
# standard function, regime, and model levels described in the
# [parameter specification workflow](params_workflow.ipynb).

# %% [markdown]
# ### Pipeline summary
#
# ```
# User defines:       grid transition = next_wealth(wealth, growth_rate)
#                     OR target grid transition = {("src","tgt"): func}
#                                                         |
#                                                         v
# Resolution:         _resolve_state_transition picks the callable
#                     per boundary using the priority list
#                                                         |
#                                                         v
# Encoding:           collect_all_regime_functions stores it under
#                     boundary-encoded key "target__next_wealth"
#                                                         |
#                                                         v
# Template:           process_regimes builds pair key "src_to_tgt"
#                     with {"next_wealth": {"growth_rate": float}}
#                                                         |
#                                                         v
# Renaming:           _rename_params_to_qnames maps
#                     growth_rate -> src_to_tgt__next_wealth__growth_rate
#                                                         |
#                                                         v
# Compilation:        flat_param_names excludes params from vmap;
#                     Q function compiled with qnames in its signature
#                                                         |
#                                                         v
# Runtime:            process_params resolves user params at 5 levels;
#                     source-regime matching enables backward compatibility
# ```
#
# **Key data structures:**
#
# | Structure | Location | Purpose |
# |---|---|---|
# | `all_functions` | `collect_all_regime_functions` | Per-regime flat dict with boundary-encoded keys |
# | `transition_keys` | `collect_all_regime_functions` | Per-regime frozenset of transition key names |
# | `params_template` | `process_regimes` | Pair keys (`source_to_target`) for boundary params |
# | `flat_param_names` | `InternalRegime` | All flattened qnames; used for vmap exclusion |
